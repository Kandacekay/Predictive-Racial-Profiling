# %%
# Import necessary libraries
import pandas as pd
from pyproj import Proj, Transformer
from pathlib import Path
import warnings
import os

# %%
# Ignore FutureWarnings from pyproj
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Read the CSV file into a Pandas DataFrame
arrest_2020 = pd.read_csv('data/2020_Racial_Profiling__RP__dataset_20231109.csv')

# Filter records for 'Arrests' in the 'Type' column
arrests_2020 = arrest_2020[arrest_2020['Type'] == 'Arrests']

# Display the resulting DataFram
arrests_2020.to_csv('data/arrests_ONLY_2020_.csv', index=False)

# %%
import pandas as pd
import pyproj
from pathlib import Path
from IPython.display import display

# Define the desired column order
desired_column_order = ['arrest_date', 'arrest_time', 'sex', 'race', 'searched', 'reason_stopped', 'search_based_on',
                        'search_found', 'race_known', 'lng', 'lat']

# Function to process the DataFrame for a specific year
def process_dataframe(df, year):
    # Create a copy of the DataFrame
    df_copy = df.copy()

    # Drop specified columns based on the year
    drop_columns = {
        2015: ['PRIMARY_KEY', 'LOCATION', 'SECTOR', 'LOCAL_FIELD1'],
        2016: ['PRIMARY_KEY', 'LOCATION', 'SECTOR', 'LOCAL_FIELD1'],
        2018: ['PRIMARY_KEY', 'LOCATION', 'APD_sector', 'CouncilDistrict', 'county_description', 'ZIP', 'CENSUS_TRACT'],
        2019: ['PRIMARY_KEY', 'LOCATION', 'APD_sector', 'CouncilDistrict', 'county_description', 'ZIP', 'CENSUS_TRACT'],
        2020: ['Stop Key', 'Type', 'TCOLE RACE ETHNICITY', 'Street_Type', 'TCOLE Result of Stop',
               'TCOLE Arrest Based On', 'CENSUS_TRACT', 'Council District', 'COUNTY', 'Custody', 'Location', 'Sector', 'Zip Code']
    }
    df_copy = df_copy.drop(columns=drop_columns.get(year, []), errors='ignore')

    # Rename columns based on the year
    rename_columns = {
        2015: {'REP_DATE': 'arrest_date', 'REP_TIME': 'arrest_time', 'SEX': 'sex', 'APD_RACE_DESC': 'race',
               'PERSON_SEARCHED_DESC': 'searched', 'REASON_FOR_STOP_DESC': 'reason_stopped',
               'SEARCH_BASED_ON_DESC': 'search_based_on', 'SEARCH_DISC_DESC': 'search_found', 'RACE_KNOWN': 'race_known',
               'X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC'},
        2016: {'REP_DATE': 'arrest_date', 'REP_TIME': 'arrest_time', 'SEX': 'sex', 'APD_RACE_DESC': 'race',
               'PERSON_SEARCHED_DESC': 'searched', 'REASON_FOR_STOP_DESC': 'reason_stopped',
               'SEARCH_BASED_ON_DESC': 'search_based_on', 'SEARCH_DISC_DESC': 'search_found', 'RACE_KNOWN': 'race_known',
              'X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC'},
        2018: {'REP_DATE': 'arrest_date', 'REP_TIME': 'arrest_time','X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC', 'RACE_KNOWN': 'race_known', 'Reason for Stop – TCOLE form': 'reason_stopped',
               'SEX': 'sex', 'APD_RACE_DESC': 'race', 'Person Search YN': 'searched', 'Search Based On': 'search_based_on',
               'Search Found': 'search_found','X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC'},
        2019: {'REP_DATE': 'arrest_date', 'REP_TIME': 'arrest_time', 'X_COORDINATE': 'XC', 'Y_COORDINATE':'yC','RACE_KNOWN': 'race_known', 'Reason for Stop – TCOLE form': 'reason_stopped',
               'SEX': 'sex', 'APD_RACE_DESC': 'race', 'Person Search YN': 'searched', 'Search Based On': 'search_based_on',
               'Search Found': 'search_found','X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC'},
        2020: {'TCOLE Sex': 'sex', 'Standardized Race Known': 'race_known',
               'Reason for Stop': 'reason_stopped', 'Search Yes or No': 'searched',
               'TCOLE Search Based On': 'search_based_on', 'TCOLE Search Found': 'search_found',
               'Standardized Race': 'race', 'Stop Date': 'arrest_date', 'Stop Time': 'arrest_time','X_COORDINATE': 'XC', 'Y_COORDINATE': 'yC'},
    }
    df_copy = df_copy.rename(columns=rename_columns.get(year, {}))
    

    for col in ['XC', 'yC']:
        if col in df_copy.columns:
            df_copy[col] = pd.to_numeric(df_copy[col], errors='coerce')
            # Convert columns to the appropriate data type
            df_copy[col] = df_copy[col].astype('float64')
            # Fill NaN values with the mean
            df_copy[col] = df_copy[col].fillna(df_copy[col].mean())

    


    # Replace missing or null values with "unknown"
    columns_to_replace = ['sex', 'race', 'reason_stopped', 'search_based_on', 'search_found', 'race_known', 'searched']
    df_copy[columns_to_replace] = df_copy[columns_to_replace].fillna('not_listed')

    # Convert columns to appropriate data types
    df_copy['arrest_date'] = pd.to_datetime(df_copy['arrest_date'])
    df_copy['arrest_time'] = df_copy['arrest_time'].astype(str).str.zfill(4)
    df_copy['arrest_time'] = pd.to_timedelta(df_copy['arrest_time'].str.zfill(4).str[:2] + ':' + df_copy['arrest_time'].str[2:] + ':00')
    df_copy['arrest_time'] = df_copy['arrest_date'] + df_copy['arrest_time']
    df_copy['sex'] = df_copy['sex'].astype('category')
    df_copy['race'] = df_copy['race'].astype('category')
    df_copy['searched'] = df_copy['searched'].astype('category')
    df_copy['reason_stopped'] = df_copy['reason_stopped'].astype('category')
    df_copy['search_based_on'] = df_copy['search_based_on'].astype('category')
    df_copy['search_found'] = df_copy['search_found'].astype('category')
    df_copy['race_known'] = df_copy['race_known'].astype('category')

    # Ensure that desired columns are present in the DataFrame
    df_copy = df_copy[desired_column_order] if all(col in df_copy.columns for col in desired_column_order) else df_copy

    return df_copy

# Function to convert XC (longitude) and yC (latitude) to actual longitude and latitude
def convert_coordinates_to_latlon(df):
    if 'XC' in df.columns and 'yC' in df.columns:
        # Define the projection for Austin, Texas (you may need to adjust this based on your data)
        austin_proj = pyproj.Proj(init='epsg:6578')  # Assuming EPSG 6578 for Austin

        # Convert XC and yC to longitude and latitude
        df['lng'], df['lat'] = austin_proj(df['XC'].values, df['yC'].values, inverse=True)

        # Drop the original XC and yC columns
        df = df.drop(['XC', 'yC'], axis=1)

    return df

def replace_null_with_mean(df):
    df['lat'] = df['lat'].fillna(df['lat'].mean())
    df['lng'] = df['lng'].fillna(df['lng'].mean())
    return df

# Loop through each DataFrame and replace null values in 'lat' and 'lng' with the mean
for year, processed_df in dfs.items():
    dfs[year] = replace_null_with_mean(processed_df)

# Dictionary to store DataFrames
dfs = {}

# List of CSV file paths
file_paths = {
    2015: "data/2015_Racial_Profiling_Arrests_20231113.csv",
    2016: "data/2016_RP_Arrests_20231113.csv",
    2018: "data/2018_RP_Arrests.csv",
    2019: "data/2019_Racial_Profiling__RP__Arrests_20231113.csv",
    2020: "data/arrests_ONLY_2020_.csv",
}

# Loop through each file, read data, and add DataFrame to the dictionary
for year, file_path in file_paths.items():
    # Read the CSV file into a Pandas DataFrame
    profiling_df = pd.read_csv(Path(file_path))
    
    # Process the DataFrame for the specific year
    processed_df = process_dataframe(profiling_df, year)

    # Convert coordinates to latitude and longitude
    processed_df = convert_coordinates_to_latlon(processed_df)

    # Add the processed DataFrame to the dictionary
    dfs[year] = processed_df

    # Check data types
    print(f"\nDTYPES FOR {year} DF:\n")
    print(processed_df.dtypes)

# Display the first few rows of each DataFrame after the conversion
for year, processed_df in dfs.items():
    print(f"\nDF for the year {year}:\n")
    display(processed_df.head(3))
# Out:
# DTYPES FOR 2015 DF:
#
# arrest_date        datetime64[ns]
# arrest_time        datetime64[ns]
# sex                      category
# race                     category
# searched                 category
# reason_stopped           category
# search_based_on          category
# search_found             category
# race_known               category
# lng                       float64
# lat                       float64
# dtype: object
#
# DTYPES FOR 2016 DF:
#
# arrest_date        datetime64[ns]
# arrest_time        datetime64[ns]
# sex                      category
# race                     category
# searched                 category
# reason_stopped           category
# search_based_on          category
# search_found             category
# race_known               category
# lng                       float64
# lat                       float64
# dtype: object
#
# DTYPES FOR 2018 DF:
#
# arrest_date        datetime64[ns]
# arrest_time        datetime64[ns]
# race_known               category
# reason_stopped           category
# sex                      category
# race                     category
# searched                 category
# search_based_on          category
# search_found             category
# lng                       float64
# lat                       float64
# dtype: object
#
# DTYPES FOR 2019 DF:
#
# arrest_date        datetime64[ns]
# arrest_time        datetime64[ns]
# race_known               category
# reason_stopped           category
# sex                      category
# race                     category
# searched                 category
# search_based_on          category
# search_found             category
# lng                       float64
# lat                       float64
# dtype: object
#
# DTYPES FOR 2020 DF:
#
# sex                      category
# race_known               category
# reason_stopped           category
# searched                 category
# search_based_on          category
# search_found             category
# race                     category
# arrest_date        datetime64[ns]
# arrest_time        datetime64[ns]
# lng                       float64
# lat                       float64
# dtype: object
#
# DF for the year 2015:
#   arrest_date         arrest_time sex                race searched  \
# 0  2015-01-01 2015-01-01 00:02:00   M  HISPANIC OR LATINO  YES = 1
# 1  2015-01-01 2015-01-01 03:17:00   M               WHITE  YES = 1
# 2  2015-01-01 2015-01-01 03:17:00   F               WHITE  YES = 1
#
#                                   reason_stopped       search_based_on  \
# 0                               CALL FOR SERVICE  INCIDENTAL TO ARREST
# 1  VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS  INCIDENTAL TO ARREST
# 2  VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS  INCIDENTAL TO ARREST
#
#   search_found                                        race_known        lng  \
# 0      NOTHING  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.734192
# 1        DRUGS  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.777689
# 2        DRUGS  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.777689
#
#          lat
# 0  30.266469
# 1  30.227663
# 2  30.227663
# DF for the year 2016:
#   arrest_date         arrest_time sex                race searched  \
# 0  2016-01-01 2016-01-01 23:55:00   F               WHITE  YES = 1
# 1  2016-01-02 2016-01-02 01:23:00   M  HISPANIC OR LATINO  YES = 1
# 2  2016-01-02 2016-01-02 01:23:00   M  HISPANIC OR LATINO   NO = 2
#
#      reason_stopped       search_based_on search_found  \
# 0  CALL FOR SERVICE  INCIDENTAL TO ARREST      NOTHING
# 1  CALL FOR SERVICE        PROBABLE CAUSE        OTHER
# 2        not_listed            not_listed   not_listed
#
#                                          race_known        lng        lat
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.721807  30.391166
# 1  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.787087  30.210685
# 2                                        not_listed -97.787087  30.210685
# DF for the year 2018:
#   arrest_date         arrest_time  \
# 0  2018-03-26 2018-03-26 20:10:00
# 1  2018-12-04 2018-12-04 10:32:00
# 2  2018-01-22 2018-01-22 09:30:00
#
#                                          race_known  \
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1                                        not_listed
# 2                                        not_listed
#
#                         reason_stopped sex   race searched  \
# 0  Violation of law other than traffic   F  WHITE      YES
# 1             Moving Traffic Violation   M  BLACK       NO
# 2             Moving Traffic Violation   F  BLACK       NO
#
#         search_based_on search_found        lng        lat
# 0  INCIDENTAL TO ARREST      NOTHING -97.753825  30.260240
# 1            not_listed   not_listed -97.742273  30.276663
# 2            not_listed   not_listed -97.694703  30.348283
# DF for the year 2019:
#   arrest_date         arrest_time  \
# 0  2019-07-17 2019-07-17 03:38:00
# 1  2019-07-27 2019-07-27 23:19:00
# 2  2019-03-17 2019-03-17 03:03:00
#
#                                          race_known  \
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 2  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
#
#                         reason_stopped sex   race searched  \
# 0             Moving Traffic Violation   M  WHITE  YES = 1
# 1             Moving Traffic Violation   M  WHITE  YES = 1
# 2  Violation of law other than traffic   F  BLACK  YES = 1
#
#         search_based_on search_found        lng        lat
# 0  INCIDENTAL TO ARREST      NOTHING -97.790452  30.227928
# 1  INCIDENTAL TO ARREST      NOTHING -97.766423  30.224811
# 2  INCIDENTAL TO ARREST         CASH -97.723585  30.288333
# DF for the year 2020:
#   sex                                        race_known  \
# 0   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 2   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
#
#              reason_stopped searched       search_based_on search_found  \
# 0  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST        DRUGS
# 1  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST      NOTHING
# 2  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST        OTHER
#
#     race arrest_date         arrest_time        lng        lat
# 0  ASIAN  2020-03-08 2020-03-08 22:42:00 -97.709511  30.281767
# 1  ASIAN  2020-07-12 2020-07-12 01:18:00 -97.774612  30.205007
# 2  ASIAN  2020-08-22 2020-08-22 00:53:00 -97.750519  30.216603

# %%
# Display null values for each DataFrame
for year, processed_df in dfs.items():
    print(f"\nDF for the year {year}:\n")
    display(processed_df.head(3))  # Display the first few rows
    print(f"\nNull values in the DataFrame for the year {year}:\n")
    display(processed_df.isnull().sum())
# Out:
# DF for the year 2015:
#   arrest_date         arrest_time sex                race searched  \
# 0  2015-01-01 2015-01-01 00:02:00   M  HISPANIC OR LATINO  YES = 1
# 1  2015-01-01 2015-01-01 03:17:00   M               WHITE  YES = 1
# 2  2015-01-01 2015-01-01 03:17:00   F               WHITE  YES = 1
#
#                                   reason_stopped       search_based_on  \
# 0                               CALL FOR SERVICE  INCIDENTAL TO ARREST
# 1  VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS  INCIDENTAL TO ARREST
# 2  VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS  INCIDENTAL TO ARREST
#
#   search_found                                        race_known        lng  \
# 0      NOTHING  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.734192
# 1        DRUGS  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.777689
# 2        DRUGS  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.777689
#
#          lat
# 0  30.266469
# 1  30.227663
# 2  30.227663
# Null values in the DataFrame for the year 2015:
# arrest_date        0
# arrest_time        0
# sex                0
# race               0
# searched           0
# reason_stopped     0
# search_based_on    0
# search_found       0
# race_known         0
# lng                0
# lat                0
# dtype: int64
# DF for the year 2016:
#   arrest_date         arrest_time sex                race searched  \
# 0  2016-01-01 2016-01-01 23:55:00   F               WHITE  YES = 1
# 1  2016-01-02 2016-01-02 01:23:00   M  HISPANIC OR LATINO  YES = 1
# 2  2016-01-02 2016-01-02 01:23:00   M  HISPANIC OR LATINO   NO = 2
#
#      reason_stopped       search_based_on search_found  \
# 0  CALL FOR SERVICE  INCIDENTAL TO ARREST      NOTHING
# 1  CALL FOR SERVICE        PROBABLE CAUSE        OTHER
# 2        not_listed            not_listed   not_listed
#
#                                          race_known        lng        lat
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.721807  30.391166
# 1  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP -97.787087  30.210685
# 2                                        not_listed -97.787087  30.210685
# Null values in the DataFrame for the year 2016:
# arrest_date        0
# arrest_time        0
# sex                0
# race               0
# searched           0
# reason_stopped     0
# search_based_on    0
# search_found       0
# race_known         0
# lng                0
# lat                0
# dtype: int64
# DF for the year 2018:
#   arrest_date         arrest_time  \
# 0  2018-03-26 2018-03-26 20:10:00
# 1  2018-12-04 2018-12-04 10:32:00
# 2  2018-01-22 2018-01-22 09:30:00
#
#                                          race_known  \
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1                                        not_listed
# 2                                        not_listed
#
#                         reason_stopped sex   race searched  \
# 0  Violation of law other than traffic   F  WHITE      YES
# 1             Moving Traffic Violation   M  BLACK       NO
# 2             Moving Traffic Violation   F  BLACK       NO
#
#         search_based_on search_found        lng        lat
# 0  INCIDENTAL TO ARREST      NOTHING -97.753825  30.260240
# 1            not_listed   not_listed -97.742273  30.276663
# 2            not_listed   not_listed -97.694703  30.348283
# Null values in the DataFrame for the year 2018:
# arrest_date        0
# arrest_time        0
# race_known         0
# reason_stopped     0
# sex                0
# race               0
# searched           0
# search_based_on    0
# search_found       0
# lng                0
# lat                0
# dtype: int64
# DF for the year 2019:
#   arrest_date         arrest_time  \
# 0  2019-07-17 2019-07-17 03:38:00
# 1  2019-07-27 2019-07-27 23:19:00
# 2  2019-03-17 2019-03-17 03:03:00
#
#                                          race_known  \
# 0  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 2  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
#
#                         reason_stopped sex   race searched  \
# 0             Moving Traffic Violation   M  WHITE  YES = 1
# 1             Moving Traffic Violation   M  WHITE  YES = 1
# 2  Violation of law other than traffic   F  BLACK  YES = 1
#
#         search_based_on search_found        lng        lat
# 0  INCIDENTAL TO ARREST      NOTHING -97.790452  30.227928
# 1  INCIDENTAL TO ARREST      NOTHING -97.766423  30.224811
# 2  INCIDENTAL TO ARREST         CASH -97.723585  30.288333
# Null values in the DataFrame for the year 2019:
# arrest_date        0
# arrest_time        0
# race_known         0
# reason_stopped     0
# sex                0
# race               0
# searched           0
# search_based_on    0
# search_found       0
# lng                0
# lat                0
# dtype: int64
# DF for the year 2020:
#   sex                                        race_known  \
# 0   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 1   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
# 2   F  NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE STOP
#
#              reason_stopped searched       search_based_on search_found  \
# 0  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST        DRUGS
# 1  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST      NOTHING
# 2  Moving Traffic Violation  YES = 1  INCIDENTAL TO ARREST        OTHER
#
#     race arrest_date         arrest_time        lng        lat
# 0  ASIAN  2020-03-08 2020-03-08 22:42:00 -97.709511  30.281767
# 1  ASIAN  2020-07-12 2020-07-12 01:18:00 -97.774612  30.205007
# 2  ASIAN  2020-08-22 2020-08-22 00:53:00 -97.750519  30.216603
# Null values in the DataFrame for the year 2020:
# sex                0
# race_known         0
# reason_stopped     0
# searched           0
# search_based_on    0
# search_found       0
# race               0
# arrest_date        0
# arrest_time        0
# lng                0
# lat                0
# dtype: int64

# %%
# Iterate over the dictionary
for year, processed_df in dfs.items():
    # Print the year
    print(f"Unique values for {year}:")

    # Iterate over columns in the data frame
    for column in processed_df.columns:
        # Use unique() to get unique values in each column
        unique_values = processed_df[column].unique()
        
        # Print the column name and unique values
        print(f"{column}: {unique_values}")

    # Add a separator for clarity between years
    print("-" * 40)
# Out:
# Unique values for 2015:
# arrest_date: <DatetimeArray>
# ['2015-01-01 00:00:00', '2015-01-02 00:00:00', '2015-01-03 00:00:00',
#  '2015-01-04 00:00:00', '2015-01-06 00:00:00', '2015-01-05 00:00:00',
#  '2015-04-11 00:00:00', '2015-01-07 00:00:00', '2015-04-24 00:00:00',
#  '2015-01-08 00:00:00',
#  ...
#  '2015-12-22 00:00:00', '2015-12-23 00:00:00', '2015-12-24 00:00:00',
#  '2015-12-25 00:00:00', '2015-12-26 00:00:00', '2015-12-27 00:00:00',
#  '2015-12-28 00:00:00', '2015-12-29 00:00:00', '2015-12-30 00:00:00',
#  '2015-12-31 00:00:00']
# Length: 363, dtype: datetime64[ns]
# arrest_time: <DatetimeArray>
# ['2015-01-01 00:02:00', '2015-01-01 03:17:00', '2015-01-01 04:26:00',
#  '2015-01-01 01:06:00', '2015-01-01 05:26:00', '2015-01-01 02:01:00',
#  '2015-01-01 17:45:00', '2015-01-01 02:21:00', '2015-01-01 02:29:00',
#  '2015-01-01 02:36:00',
#  ...
#  '2015-12-31 21:51:00', '2015-12-31 21:38:00', '2015-12-31 21:45:00',
#  '2015-12-31 21:57:00', '2015-12-31 23:02:00', '2015-12-31 23:00:00',
#  '2015-12-31 22:28:00', '2015-12-31 22:59:00', '2015-12-31 23:35:00',
#  '2015-12-31 23:03:00']
# Length: 8289, dtype: datetime64[ns]
# sex: ['M', 'F']
# Categories (2, object): ['F', 'M']
# race: ['HISPANIC OR LATINO', 'WHITE', 'ASIAN', 'BLACK', 'MIDDLE EASTERN', 'UNKNOWN', 'AMERICAN INDIAN/ALASKAN NATIVE', 'HAWAIIAN/PACIFIC ISLANDER']
# Categories (8, object): ['AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN', 'BLACK', 'HAWAIIAN/PACIFIC ISLANDER', 'HISPANIC OR LATINO', 'MIDDLE EASTERN', 'UNKNOWN', 'WHITE']
# searched: ['YES = 1', 'NO = 2']
# Categories (2, object): ['NO = 2', 'YES = 1']
# reason_stopped: ['CALL FOR SERVICE', 'VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS', 'CONSENSUAL CONTACT', 'PRE-EXISTING KNOWLEDGE', 'not_listed', ..., 'SUSPICIOUS PERSON / VEHICLE', 'VIOLATION OF PENAL CODE', 'OTHER', 'MOTOR VEHICLE DRIVER', 'WATER SAFETY ACT']
# Length: 11
# Categories (11, object): ['CALL FOR SERVICE', 'CONSENSUAL CONTACT', 'MOTOR VEHICLE DRIVER', 'OTHER', ..., 'VIOLATION OF PENAL CODE', 'VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS', 'WATER SAFETY ACT', 'not_listed']
# search_based_on: ['INCIDENTAL TO ARREST', 'FRISK FOR SAFETY', 'PROBABLE CAUSE', 'not_listed', 'INVENTORY OF TOWED VEHICLE', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'CONSENT']
# Categories (7, object): ['CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'FRISK FOR SAFETY', 'INCIDENTAL TO ARREST', 'INVENTORY OF TOWED VEHICLE', 'PROBABLE CAUSE', 'not_listed']
# search_found: ['NOTHING', 'DRUGS', 'OTHER', 'ALCOHOL', 'CASH', 'WEAPONS', 'not_listed']
# Categories (7, object): ['ALCOHOL', 'CASH', 'DRUGS', 'NOTHING', 'OTHER', 'WEAPONS', 'not_listed']
# race_known: ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP', 'not_listed']
# Categories (3, object): ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP', 'not_listed']
# lng: [-97.73419151 -97.77768892 -97.76017255 ... -97.69821944 -97.6935753
#  -97.72049744]
# lat: [30.26646917 30.22766255 30.27421319 ... 30.41715374 30.42079608
#  30.33530445]
# ----------------------------------------
# Unique values for 2016:
# arrest_date: <DatetimeArray>
# ['2016-01-01 00:00:00', '2016-01-02 00:00:00', '2016-01-03 00:00:00',
#  '2016-01-04 00:00:00', '2016-01-10 00:00:00', '2016-01-05 00:00:00',
#  '2016-01-15 00:00:00', '2016-01-06 00:00:00', '2016-01-07 00:00:00',
#  '2016-01-22 00:00:00',
#  ...
#  '2016-12-27 00:00:00', '2016-12-22 00:00:00', '2016-12-23 00:00:00',
#  '2016-12-24 00:00:00', '2016-12-25 00:00:00', '2016-12-26 00:00:00',
#  '2016-12-29 00:00:00', '2016-12-28 00:00:00', '2016-12-30 00:00:00',
#  '2016-12-31 00:00:00']
# Length: 366, dtype: datetime64[ns]
# arrest_time: <DatetimeArray>
# ['2016-01-01 23:55:00', '2016-01-02 01:23:00', '2016-01-01 22:12:00',
#  '2016-01-01 06:58:00', '2016-01-01 02:41:00', '2016-01-01 02:50:00',
#  '2016-01-01 23:10:00', '2016-01-02 22:57:00', '2016-01-02 04:45:00',
#  '2016-01-03 22:00:00',
#  ...
#  '2016-12-29 18:25:00', '2016-12-31 00:35:00', '2016-12-30 02:16:00',
#  '2016-12-29 19:12:00', '2016-12-29 22:30:00', '2016-12-30 21:19:00',
#  '2016-12-29 23:20:00', '2016-12-31 08:17:00', '2016-12-30 23:54:00',
#  '2016-12-31 02:11:00']
# Length: 8238, dtype: datetime64[ns]
# sex: ['F', 'M']
# Categories (2, object): ['F', 'M']
# race: ['WHITE', 'HISPANIC OR LATINO', 'BLACK', 'ASIAN', 'MIDDLE EASTERN', 'UNKNOWN', 'HAWAIIAN/PACIFIC ISLANDER', 'AMERICAN INDIAN/ALASKAN NATIVE']
# Categories (8, object): ['AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN', 'BLACK', 'HAWAIIAN/PACIFIC ISLANDER', 'HISPANIC OR LATINO', 'MIDDLE EASTERN', 'UNKNOWN', 'WHITE']
# searched: ['YES = 1', 'NO = 2']
# Categories (2, object): ['NO = 2', 'YES = 1']
# reason_stopped: ['CALL FOR SERVICE', 'not_listed', 'VIOLATION OF PENAL CODE', 'OTHER', 'VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS', ..., 'SUSPICIOUS PERSON / VEHICLE', 'PRE-EXISTING KNOWLEDGE', 'CONSENSUAL CONTACT', 'MOTOR VEHICLE DRIVER', 'WATER SAFETY ACT']
# Length: 11
# Categories (11, object): ['CALL FOR SERVICE', 'CONSENSUAL CONTACT', 'MOTOR VEHICLE DRIVER', 'OTHER', ..., 'VIOLATION OF PENAL CODE', 'VIOLATION OF TRANSPORTATION CODE/VEHICLE LAWS', 'WATER SAFETY ACT', 'not_listed']
# search_based_on: ['INCIDENTAL TO ARREST', 'PROBABLE CAUSE', 'not_listed', 'CONSENT', 'FRISK FOR SAFETY', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'INVENTORY OF TOWED VEHICLE']
# Categories (7, object): ['CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'FRISK FOR SAFETY', 'INCIDENTAL TO ARREST', 'INVENTORY OF TOWED VEHICLE', 'PROBABLE CAUSE', 'not_listed']
# search_found: ['NOTHING', 'OTHER', 'not_listed', 'DRUGS', 'ALCOHOL', 'WEAPONS', 'CASH']
# Categories (7, object): ['ALCOHOL', 'CASH', 'DRUGS', 'NOTHING', 'OTHER', 'WEAPONS', 'not_listed']
# race_known: ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'not_listed', 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP']
# Categories (3, object): ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP', 'not_listed']
# lng: [-97.72180726 -97.78708695 -97.70582263 ... -97.73431968 -97.8120911
#  -97.82291162]
# lat: [30.39116635 30.21068507 30.34405605 ... 30.38940992 30.21527223
#  30.17385381]
# ----------------------------------------
# Unique values for 2018:
# arrest_date: <DatetimeArray>
# ['2018-03-26 00:00:00', '2018-12-04 00:00:00', '2018-01-22 00:00:00',
#  '2018-12-23 00:00:00', '2018-01-07 00:00:00', '2018-02-02 00:00:00',
#  '2018-12-18 00:00:00', '2018-11-30 00:00:00', '2018-12-15 00:00:00',
#  '2018-03-04 00:00:00',
#  ...
#  '2018-12-19 00:00:00', '2018-12-24 00:00:00', '2018-12-21 00:00:00',
#  '2018-12-22 00:00:00', '2018-12-25 00:00:00', '2018-12-20 00:00:00',
#  '2018-12-29 00:00:00', '2018-12-30 00:00:00', '2018-12-27 00:00:00',
#  '2018-12-26 00:00:00']
# Length: 365, dtype: datetime64[ns]
# arrest_time: <DatetimeArray>
# ['2018-03-26 20:10:00', '2018-12-04 10:32:00', '2018-01-22 09:30:00',
#  '2018-12-23 09:06:00', '2018-01-07 10:17:00', '2018-02-02 23:59:00',
#  '2018-12-18 18:41:00', '2018-11-30 02:55:00', '2018-12-15 00:38:00',
#  '2018-03-04 02:07:00',
#  ...
#  '2018-12-13 02:59:00', '2018-09-27 00:32:00', '2018-12-15 21:25:00',
#  '2018-12-31 22:00:00', '2018-12-23 22:31:00', '2018-12-26 23:20:00',
#  '2018-12-18 22:03:00', '2018-11-21 19:09:00', '2018-12-24 18:13:00',
#  '2018-12-15 18:50:00']
# Length: 10026, dtype: datetime64[ns]
# race_known: ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'not_listed', 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP']
# Categories (3, object): ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP', 'not_listed']
# reason_stopped: ['Violation of law other than traffic', 'Moving Traffic Violation', 'Pre-existing knowledge (i.e. warrant)']
# Categories (3, object): ['Moving Traffic Violation', 'Pre-existing knowledge (i.e. warrant)', 'Violation of law other than traffic']
# sex: ['F', 'M', 'U', 'not_listed']
# Categories (4, object): ['F', 'M', 'U', 'not_listed']
# race: ['WHITE', 'BLACK', 'HISPANIC OR LATINO', 'MIDDLE EASTERN', 'ASIAN', 'HAWAIIAN/PACIFIC ISLANDER', 'UNKNOWN', 'AMERICAN INDIAN/ALASKAN NATIVE', 'not_listed']
# Categories (9, object): ['AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN', 'BLACK', 'HAWAIIAN/PACIFIC ISLANDER', ..., 'MIDDLE EASTERN', 'UNKNOWN', 'WHITE', 'not_listed']
# searched: ['YES', 'NO']
# Categories (2, object): ['NO', 'YES']
# search_based_on: ['INCIDENTAL TO ARREST', 'not_listed', 'PROBABLE CAUSE', 'FRISK FOR SAFETY', 'CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'INVENTORY OF TOWED VEHICLE']
# Categories (7, object): ['CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'FRISK FOR SAFETY', 'INCIDENTAL TO ARREST', 'INVENTORY OF TOWED VEHICLE', 'PROBABLE CAUSE', 'not_listed']
# search_found: ['NOTHING', 'not_listed', 'OTHER', 'CASH', 'DRUGS', 'WEAPONS', 'ALCOHOL']
# Categories (7, object): ['ALCOHOL', 'CASH', 'DRUGS', 'NOTHING', 'OTHER', 'WEAPONS', 'not_listed']
# lng: [-97.75382505 -97.7422732  -97.69470345 ... -97.72288324 -97.74048929
#  -97.76511165]
# lat: [30.26024038 30.27666335 30.34828335 ... 30.2577957  30.22734393
#  30.47589865]
# ----------------------------------------
# Unique values for 2019:
# arrest_date: <DatetimeArray>
# ['2019-07-17 00:00:00', '2019-07-27 00:00:00', '2019-03-17 00:00:00',
#  '2019-07-13 00:00:00', '2019-03-30 00:00:00', '2019-04-12 00:00:00',
#  '2019-06-14 00:00:00', '2019-10-22 00:00:00', '2019-03-31 00:00:00',
#  '2019-12-27 00:00:00',
#  ...
#  '2019-12-08 00:00:00', '2019-12-14 00:00:00', '2019-11-18 00:00:00',
#  '2019-12-30 00:00:00', '2019-12-25 00:00:00', '2019-12-01 00:00:00',
#  '2019-12-20 00:00:00', '2019-12-11 00:00:00', '2019-12-26 00:00:00',
#  '2019-11-15 00:00:00']
# Length: 365, dtype: datetime64[ns]
# arrest_time: <DatetimeArray>
# ['2019-07-17 03:38:00', '2019-07-27 23:19:00', '2019-03-17 03:03:00',
#  '2019-07-13 00:26:00', '2019-03-30 23:53:00', '2019-04-12 20:52:00',
#  '2019-06-14 22:33:00', '2019-10-22 14:27:00', '2019-03-31 08:25:00',
#  '2019-12-27 17:11:00',
#  ...
#  '2019-09-27 23:15:00', '2019-10-09 11:48:00', '2019-12-13 01:50:00',
#  '2019-12-19 23:52:00', '2019-12-11 14:09:00', '2019-11-16 21:47:00',
#  '2019-12-23 01:35:00', '2019-12-20 23:29:00', '2019-12-19 15:28:00',
#  '2019-11-26 02:22:00']
# Length: 7032, dtype: datetime64[ns]
# race_known: ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'not_listed', 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP']
# Categories (3, object): ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP', 'not_listed']
# reason_stopped: ['Moving Traffic Violation', 'Violation of law other than traffic', 'Pre-existing knowledge (i.e. warrant)']
# Categories (3, object): ['Moving Traffic Violation', 'Pre-existing knowledge (i.e. warrant)', 'Violation of law other than traffic']
# sex: ['M', 'F', 'not_listed']
# Categories (3, object): ['F', 'M', 'not_listed']
# race: ['WHITE', 'BLACK', 'HISPANIC OR LATINO', 'ASIAN', 'HAWAIIAN/PACIFIC ISLANDER', 'MIDDLE EASTERN', 'UNKNOWN', 'AMERICAN INDIAN/ALASKAN NATIVE', 'not_listed']
# Categories (9, object): ['AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN', 'BLACK', 'HAWAIIAN/PACIFIC ISLANDER', ..., 'MIDDLE EASTERN', 'UNKNOWN', 'WHITE', 'not_listed']
# searched: ['YES = 1', 'not_listed', 'NO = 2']
# Categories (3, object): ['NO = 2', 'YES = 1', 'not_listed']
# search_based_on: ['INCIDENTAL TO ARREST', 'not_listed', 'PROBABLE CAUSE', 'FRISK FOR SAFETY', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'INVENTORY OF TOWED VEHICLE', 'CONSENT']
# Categories (7, object): ['CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'FRISK FOR SAFETY', 'INCIDENTAL TO ARREST', 'INVENTORY OF TOWED VEHICLE', 'PROBABLE CAUSE', 'not_listed']
# search_found: ['NOTHING', 'CASH', 'ALCOHOL', 'OTHER', 'DRUGS', 'not_listed', 'WEAPONS']
# Categories (7, object): ['ALCOHOL', 'CASH', 'DRUGS', 'NOTHING', 'OTHER', 'WEAPONS', 'not_listed']
# lng: [-97.790452   -97.76642303 -97.7235849  ... -97.78041322 -97.70983251
#  -97.67614787]
# lat: [30.22792759 30.22481071 30.28833342 ... 30.21961447 30.32393943
#  30.33058649]
# ----------------------------------------
# Unique values for 2020:
# sex: ['F', 'M']
# Categories (2, object): ['F', 'M']
# race_known: ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP']
# Categories (2, object): ['NO - RACE OR ETHNICITY WAS NOT KNOWN BEFORE S..., 'YES - RACE OR ETHNICITY WAS KNOWN BEFORE STOP']
# reason_stopped: ['Moving Traffic Violation', 'Violation of law other than traffic', 'Pre-existing knowledge (i.e. warrant)']
# Categories (3, object): ['Moving Traffic Violation', 'Pre-existing knowledge (i.e. warrant)', 'Violation of law other than traffic']
# searched: ['YES = 1', 'NO = 2']
# Categories (2, object): ['NO = 2', 'YES = 1']
# search_based_on: ['INCIDENTAL TO ARREST', 'FRISK FOR SAFETY', 'No Search', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'PROBABLE CAUSE', 'TOWING OF MOTOR VEHICLE', 'CONSENT']
# Categories (7, object): ['CONSENT', 'CONTRABAND/EVIDENCE IN PLAIN VIEW', 'FRISK FOR SAFETY', 'INCIDENTAL TO ARREST', 'No Search', 'PROBABLE CAUSE', 'TOWING OF MOTOR VEHICLE']
# search_found: ['DRUGS', 'NOTHING', 'OTHER', 'No Search', 'ALCOHOL', 'CASH', 'WEAPONS']
# Categories (7, object): ['ALCOHOL', 'CASH', 'DRUGS', 'NOTHING', 'No Search', 'OTHER', 'WEAPONS']
# race: ['ASIAN', 'MIDDLE EASTERN', 'BLACK', 'HISPANIC OR LATINO', 'WHITE', 'AMERICAN INDIAN/ALASKAN NATIVE', 'HAWAIIAN/PACIFIC ISLANDER']
# Categories (7, object): ['AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN', 'BLACK', 'HAWAIIAN/PACIFIC ISLANDER', 'HISPANIC OR LATINO', 'MIDDLE EASTERN', 'WHITE']
# arrest_date: <DatetimeArray>
# ['2020-03-08 00:00:00', '2020-07-12 00:00:00', '2020-08-22 00:00:00',
#  '2020-04-11 00:00:00', '2020-10-10 00:00:00', '2020-07-19 00:00:00',
#  '2020-11-23 00:00:00', '2020-11-01 00:00:00', '2020-10-02 00:00:00',
#  '2020-01-23 00:00:00',
#  ...
#  '2020-10-27 00:00:00', '2020-09-22 00:00:00', '2020-04-09 00:00:00',
#  '2020-06-17 00:00:00', '2020-08-01 00:00:00', '2020-08-02 00:00:00',
#  '2020-07-02 00:00:00', '2020-11-30 00:00:00', '2020-06-18 00:00:00',
#  '2020-04-08 00:00:00']
# Length: 366, dtype: datetime64[ns]
# arrest_time: <DatetimeArray>
# ['2020-03-08 22:42:00', '2020-07-12 01:18:00', '2020-08-22 00:53:00',
#  '2020-04-11 15:23:00', '2020-10-10 00:02:00', '2020-07-19 03:03:00',
#  '2020-11-23 02:43:00', '2020-11-01 22:02:00', '2020-10-02 22:39:00',
#  '2020-01-23 01:14:00',
#  ...
#  '2020-11-29 18:26:00', '2020-04-21 00:39:00', '2020-01-24 21:44:00',
#  '2020-01-08 18:56:00', '2020-07-21 17:19:00', '2020-03-21 17:39:00',
#  '2020-11-06 18:12:00', '2020-10-15 07:15:00', '2020-03-24 08:10:00',
#  '2020-06-02 05:37:00']
# Length: 3814, dtype: datetime64[ns]
# lng: [-97.70951146 -97.77461202 -97.75051881 ... -97.74417207 -97.73579903
#  -97.67301757]
# lat: [30.28176698 30.2050073  30.21660302 ... 30.3900547  30.37912878
#  30.41731862]
# ----------------------------------------

# %%
# Save each DataFrame to a CSV file
for year, processed_df in dfs.items():
    file_path = f'data/cleaned_data/{year}_cleaned_data.csv'
    processed_df.to_csv(file_path, index=False)
    print(f'DataFrame for the year {year} saved to: {file_path}')

# Combine DataFrames into one DataFrame
combined_df = pd.concat(dfs.values(), ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_file_path = 'data/cleaned_data/combined_data.csv'
combined_df.to_csv(combined_file_path, index=False)
print(f'Combined DataFrame saved to: {combined_file_path}')
# Out:
# DataFrame for the year 2015 saved to: data/cleaned_data/2015_cleaned_data.csv
# DataFrame for the year 2016 saved to: data/cleaned_data/2016_cleaned_data.csv
# DataFrame for the year 2018 saved to: data/cleaned_data/2018_cleaned_data.csv
# DataFrame for the year 2019 saved to: data/cleaned_data/2019_cleaned_data.csv
# DataFrame for the year 2020 saved to: data/cleaned_data/2020_cleaned_data.csv
# Combined DataFrame saved to: data/cleaned_data/combined_data.csv
